# %%
from google.colab import drive
import os

# %%
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
os.chdir("gdrive/My Drive/dizz2")

# %%
os.listdir()
# Out:
# ['GSK per min.csv',
#  'data_preparation.py',
#  'data_preprocessing.py',
#  '__pycache__',
#  'model_refinement.py',
#  'model_development.py',
#  'best_model_selection.py',
#  'report60_20200913_223215.csv',
#  'report120_20200914_014758.csv',
#  'report180_20200914_095351.csv',
#  'main.py',
#  'visualisation.py',
#  'lr_strategy.py',
#  'Closing_prices_plot_20200915_102430.png',
#  'Original_Prediction_represent_20200915_102431.png',
#  'lr_logs_file_20200915_102525.txt',
#  'LR_scheme_representation_20200915_102525.png',
#  'Copy of colab_main.ipynb']

# %%
import main
# Out:
# Data_preparation imported
# Data_Preprocessing imported
# Visualisation imported
# CAUTION -- this is a functionality test run --
# Change MODE into "official" to have a full run
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-63b75181c34a> in <module>()
# ----> 1 import main
#
# /content/gdrive/My Drive/dizz2/main.py in <module>()
#     107     run_func_test = model_development.grid_cv(functionality_test_models, 1, slide_data, slide_labels,
#     108                                               K_FOLDS, EPOCHS, BATCH_SIZE,
# --> 109                                               [lr_callback, early_stop_callback], REPORT_COLS)
#     110 else:
#     111     run60 = model_development.grid_cv(models60, 60, slide_data, slide_labels,
#
# ...
